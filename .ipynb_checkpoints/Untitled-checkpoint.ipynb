# %%
import warnings
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv('features.csv',encoding='unicode_escape')
data=data.dropna()
data
# Out:
#           id  pos  neg   posFrag   negFrag  job  fam   jobFrag   famFrag  \
# 0    6486006    1    1  0.030303  0.030303    1    1  0.030303  0.030303
# 1    6566002    1    0  0.058824  0.000000    1    0  0.039216  0.000000
# 2    6486007    1    0  0.040000  0.000000    0    0  0.000000  0.000000
# 3    6566001    1    0  0.032258  0.000000    1    0  0.032258  0.000000
# 4    6486004    1    0  0.045455  0.000000    0    1  0.000000  0.045455
# ..       ...  ...  ...       ...       ...  ...  ...       ...       ...
# 161  6427007    0    0  0.000000  0.000000    0    0  0.000000  0.000000
# 162  6427008    1    0  0.096774  0.000000    0    1  0.000000  0.096774
# 163  6427005    1    0  0.250000  0.000000    0    0  0.000000  0.000000
# 164  6427006    1    0  0.033333  0.000000    1    0  0.100000  0.000000
# 165  6427004    0    0  0.000000  0.000000    0    0  0.000000  0.000000
#
#      age_index  gender  avatar_index  peopleSenseCount  peopleSenseLearn
# 0            3       1             2              21.0          0.207792
# 1            2       1             0              32.0          1.433101
# 2            1       0             2              38.0          0.783456
# 3            0       1             0              12.0         -0.730769
# 4            1       1             2              31.0         -0.225000
# ..         ...     ...           ...               ...               ...
# 161          3       0             0               2.0         10.000000
# 162          2       0             0              24.0          0.589565
# 163          2       0             2               8.0          5.880952
# 164          2       1             0              27.0         -0.807082
# 165          2       1             0              38.0         -0.597330
#
# [164 rows x 14 columns]

# %%
columns = list(data)
nColumns = len(columns)

result = pd.DataFrame(np.zeros((nColumns, nColumns)), columns=columns)

# %%
from scipy.stats.stats import pearsonr
#Pearson correlation as a metric of indepedance
for col_a in range(nColumns):
    for col_b in range(nColumns):
        result.iloc[[col_a], [col_b]] = round(pearsonr(data.loc[:, columns[col_a]], data.loc[:,  columns[col_b]])[0],2)

# %%
fig, ax = plt.subplots(figsize=(10,10))
im = ax.imshow(result)
ax.set_xticks(np.arange(nColumns))
ax.set_yticks(np.arange(nColumns))
ax.set_xticklabels(columns)
ax.set_yticklabels(columns)
plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")
for i in range(nColumns):
    for j in range(nColumns):
        text = ax.text(j, i, result.iloc[i, j],ha="center", va="center", color="w")
                   
ax.set_title('PCC')
plt.show()
